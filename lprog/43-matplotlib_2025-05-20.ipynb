# %% [markdown]
# # Visualização de dados em Python
#
# - Matplotlib
# - Seaborn

# %% [markdown]
# - import matplotlib.pyplot as plt
# - from matplotlib import pyplot as plt

# %%
import random as rd
import numpy as np
import matplotlib.pyplot as plt

dados1 = rd.sample(range(100), k=20)
dados2 = rd.sample(range(100), k=20)
plt.plot(dados1, dados2)
plt.show()

# %%
x = range(5)
x = np.array(x)
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
print("Tipo de ax = ", type(ax))
print("Conteúdo de ax[0] = ", ax[0])
print("Conteúdo de ax[1] = ", ax[1])
ax[0].plot(x, x, label='eq_1')
ax[0].plot(x, x**2, label='eq_2')
ax[0].plot(x, x**3, label='eq_3')
ax[0].set_xlabel('Eixo x')
ax[0].set_ylabel('Eixo y')
ax[0].set_title("Gráfico 1")
ax[0].legend()
ax[1].plot(x, x, 'r--', label='eq_1')
ax[1].plot(x**2, x, 'b--', label='eq_2')
ax[1].plot(x**3, x, 'g--', label='eq_3')
ax[1].set_xlabel('Novo Eixo x')
ax[1].set_ylabel('Novo Eixo y')
ax[1].set_title("Gráfico 2")
ax[1].legend()
plt.show()
# Out:
# Tipo de ax =  <class 'numpy.ndarray'>
# Conteúdo de ax[0] =  Axes(0.125,0.11;0.352273x0.77)
# Conteúdo de ax[1] =  Axes(0.547727,0.11;0.352273x0.77)

# %%
x = range(5)
x = np.array(x)
fig = plt.subplots(figsize=(12, 5))
plt.subplot(121)
plt.plot(x, x, label='eq_1')
plt.plot(x, x**2, label='eq_2')
plt.plot(x, x**3, label='eq_3')
plt.title("Gráfico 1")
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.legend()
plt.subplot(122)
plt.plot(x, x, 'r--', label='eq_1')
plt.plot(x**2, x, 'b--', label='eq_2')
plt.plot(x**3, x, 'g--', label='eq_3')
plt.title("Gráfico 2")
plt.xlabel('Novo eixo x')
plt.ylabel('Novo eixo y')
plt.legend()
plt.show()

# %%
import pandas as pd

dados = {'turma': ['A', 'B', 'C'], 'qtde_alunos': [33, 50, 45]}
df = pd.DataFrame(dados)
df
# Out:
#   turma  qtde_alunos
# 0     A           33
# 1     B           50
# 2     C           45

# %%
df.plot(x='turma', y='qtde_alunos', kind='bar')
# Out:
# <Axes: xlabel='turma'>

# %%
df.plot(x='turma', y='qtde_alunos', kind='barh')
# Out:
# <Axes: ylabel='turma'>

# %%
df.plot(x='turma', y='qtde_alunos', kind='line')
# Out:
# <Axes: xlabel='turma'>

# %%
df.set_index('turma').plot(y='qtde_alunos', kind='pie')
# Out:
# <Axes: ylabel='qtde_alunos'>

# %%
URL = 'https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/arquivos/ie/etanol/exportacao-etanol-hidratado-2012-2021-m3.csv/@@download/file'
df_etanol = pd.read_csv(URL, sep=';')

# %%
df_etanol.head()
# Out:
#     ANO            PRODUTO MOVIMENTO COMERCIAL UNIDADE        JAN         FEV  \
# 0  2012  ETANOL HIDRATADO           EXPORTAÇÃO      m3  23240,019    37701,75
# 1  2013  ETANOL HIDRATADO           EXPORTAÇÃO      m3  179411,21  103192,127
# 2  2014  ETANOL HIDRATADO           EXPORTAÇÃO      m3  92985,931   59806,023
# 3  2015  ETANOL HIDRATADO           EXPORTAÇÃO      m3  57560,264    31102,65
# 4  2016  ETANOL HIDRATADO           EXPORTAÇÃO      m3  73399,284  192061,229
#
#          MAR        ABR        MAI         JUN         JUL        AGO  \
# 0  32544,915  26110,145  40838,313   38463,751  102502,628  65235,388
# 1  25823,789  14490,489   30662,71  103236,547   90358,921  94403,433
# 2  26149,936  37560,243  19795,784   64522,802   49595,918  41999,877
# 3  71837,292   8429,754  16760,704   24468,809  140172,215  72711,237
# 4  75194,772  21283,088  59300,976  141364,399   94266,978  58584,587
#
#           SET         OUT         NOV         DEZ        TOTAL
# 0  187096,731  194938,064  124139,351  213683,449  1086494,504
# 1  115838,513  161414,721  122145,833   69596,688  1110574,981
# 2   46301,679   72902,913   50971,719   78438,177   641031,002
# 3   52264,181  107861,466   82277,943  171143,391   836589,906
# 4  126300,867   22454,195   20054,398   20054,398   904319,171

# %%
df_etanol.drop(columns=['PRODUTO', 'MOVIMENTO COMERCIAL', 'UNIDADE'],
               inplace=True)
for mes in 'JAN FEV MAR ABR MAI JUN JUL AGO SET OUT NOV DEZ TOTAL'.split():
    df_etanol[mes] = df_etanol[mes].str.replace(',', '.')
df_etanol = df_etanol.astype(float)
df_etanol['ANO'] = df_etanol['ANO'].astype(int)

df_etanol.head(2)
# Out:
#     ANO         JAN         FEV        MAR        ABR        MAI         JUN  \
# 0  2012   23240.019   37701.750  32544.915  26110.145  40838.313   38463.751
# 1  2013  179411.210  103192.127  25823.789  14490.489  30662.710  103236.547
#
#           JUL        AGO         SET         OUT         NOV         DEZ  \
# 0  102502.628  65235.388  187096.731  194938.064  124139.351  213683.449
# 1   90358.921  94403.433  115838.513  161414.721  122145.833   69596.688
#
#          TOTAL
# 0  1086494.504
# 1  1110574.981

# %%
df_etanol.plot(x='ANO',
               y='JAN',
               kind='bar',
               figsize=(10, 5),
               rot=0,
               fontsize=12,
               legend=False)
df_etanol.plot(x='ANO',
               y='JAN',
               kind='line',
               figsize=(10, 5),
               rot=0,
               fontsize=12,
               legend=False)
# Out:
# <Axes: xlabel='ANO'>

# %%
df_etanol[['ANO', 'JAN', 'FEV']].plot(x='ANO',
                                      kind='bar',
                                      figsize=(10, 5),
                                      rot=0,
                                      fontsize=12)
# Out:
# <Axes: xlabel='ANO'>

# %% [markdown]
# ## Seaborn
#
#     conda install seaborn

# %%
import seaborn as sns

# %%
df_tips = sns.load_dataset('tips')

# %%
df_tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
sns.barplot(data=df_tips, x='sex', y='total_bill', ax=ax[0])
sns.barplot(data=df_tips, x='sex', y='total_bill', ax=ax[1], estimator=sum)
sns.barplot(data=df_tips, x='sex', y='total_bill', ax=ax[2], estimator=len)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
plt.figure(figsize=(10, 5))
ax = sns.barplot(x="day", y="total_bill", data=df_tips)
ax.axes.set_title("Venda média diária", fontsize=14)
ax.set_xlabel("Dia", fontsize=14)
ax.set_ylabel("Venda média ", fontsize=14)
ax.tick_params(labelsize=14)

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=df_tips, x="day")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=df_tips, x="day", hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=df_tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
